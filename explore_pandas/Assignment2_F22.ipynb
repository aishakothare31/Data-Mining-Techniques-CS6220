# %%
import pandas as pd
import seaborn as sea
from matplotlib import pyplot as plt

# %% [markdown]
# # Q1 Iris dataset : todo: 1.3.4 1.3.5

# %%
iris_attr=['SepalLength_cm','SepalWidth_cm','PetalLength_cm','PetalWidth_cm','Specie']
iris_data = pd.read_table('/Users/aishakothare/Desktop/DMT/iris.data', sep=',', names=iris_attr, header=None,engine='python')

# %%
iris_data
# Out:
#      SepalLength_cm  SepalWidth_cm  PetalLength_cm  PetalWidth_cm  \
# 0               5.1            3.5             1.4            0.2
# 1               4.9            3.0             1.4            0.2
# 2               4.7            3.2             1.3            0.2
# 3               4.6            3.1             1.5            0.2
# 4               5.0            3.6             1.4            0.2
# ..              ...            ...             ...            ...
# 145             6.7            3.0             5.2            2.3
# 146             6.3            2.5             5.0            1.9
# 147             6.5            3.0             5.2            2.0
# 148             6.2            3.4             5.4            2.3
# 149             5.9            3.0             5.1            1.8
#
#              Specie
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# ...

# %%
iris_data.isnull().sum()
# Out:
# SepalLength_cm    0
# SepalWidth_cm     0
# PetalLength_cm    0
# PetalWidth_cm     0
# Specie            0
# dtype: int64

# %%
iris_data.shape
# Out:
# (150, 5)

# %%
iris_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   SepalLength_cm  150 non-null    float64
#  1   SepalWidth_cm   150 non-null    float64
#  2   PetalLength_cm  150 non-null    float64
#  3   PetalWidth_cm   150 non-null    float64
#  4   Specie          150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# ## Q1.1 : Compute and display summary statistics for each feature available in the dataset

# %%
iris_data.describe()
# Out:
#        SepalLength_cm  SepalWidth_cm  PetalLength_cm  PetalWidth_cm
# count      150.000000     150.000000      150.000000     150.000000
# mean         5.843333       3.054000        3.758667       1.198667
# std          0.828066       0.433594        1.764420       0.763161
# min          4.300000       2.000000        1.000000       0.100000
# 25%          5.100000       2.800000        1.600000       0.300000
# 50%          5.800000       3.000000        4.350000       1.300000
# 75%          6.400000       3.300000        5.100000       1.800000
# max          7.900000       4.400000        6.900000       2.500000

# %%
iris_data.var()
# Out:
# /var/folders/w7/4qn17rqj6dj91d1s17qbtz700000gn/T/ipykernel_37394/2984775046.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   iris_data.var()
# SepalLength_cm    0.685694
# SepalWidth_cm     0.188004
# PetalLength_cm    3.113179
# PetalWidth_cm     0.582414
# dtype: float64

# %% [markdown]
# ## Q1.2 box-plot for each feature

# %%
iris_data.plot(kind='box',layout=(4,1),figsize=(10,10),color='red',grid=True)
# Out:
# <AxesSubplot: >

# %% [markdown]
# ## Histograms

# %%
iris_data.hist(density = True)
# Out:
# array([[<AxesSubplot: title={'center': 'SepalLength_cm'}>,
#         <AxesSubplot: title={'center': 'SepalWidth_cm'}>],
#        [<AxesSubplot: title={'center': 'PetalLength_cm'}>,
#         <AxesSubplot: title={'center': 'PetalWidth_cm'}>]], dtype=object)

# %%
iris_data.plot(kind='hist', figsize=(5,5), rwidth=0.6)
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %% [markdown]
# ## classwise visualization

# %%
setosa=iris_data.loc[iris_data['Specie']=='Iris-setosa']
virginica=iris_data.loc[iris_data['Specie']=='Iris-virginica']
versicolor=iris_data.loc[iris_data['Specie']=='Iris-versicolor']
iris_data['id']=iris_data.index
# setosa.plot(x='id',y=['SepalLength_cm','SepalWidth_cm','PetalLength_cm','PetalWidth_cm'],kind='hist',figsize=(5,5), rwidth=0.6,title='setosa')
# virginica.plot(x='id',y=['SepalLength_cm','SepalWidth_cm','PetalLength_cm','PetalWidth_cm'],kind='hist',figsize=(5,5), rwidth=0.6,title='virginica')
# versicolor.plot(x='id',y=['SepalLength_cm','SepalWidth_cm','PetalLength_cm','PetalWidth_cm'],kind='hist',figsize=(5,5), rwidth=0.6, title='versicolor')

# %%
setosa.hist(density=True)
# Out:
# array([[<AxesSubplot: title={'center': 'SepalLength_cm'}>,
#         <AxesSubplot: title={'center': 'SepalWidth_cm'}>],
#        [<AxesSubplot: title={'center': 'PetalLength_cm'}>,
#         <AxesSubplot: title={'center': 'PetalWidth_cm'}>]], dtype=object)

# %%
virginica.hist(density=True)
# Out:
# array([[<AxesSubplot: title={'center': 'SepalLength_cm'}>,
#         <AxesSubplot: title={'center': 'SepalWidth_cm'}>],
#        [<AxesSubplot: title={'center': 'PetalLength_cm'}>,
#         <AxesSubplot: title={'center': 'PetalWidth_cm'}>]], dtype=object)

# %%
versicolor.hist(density=-True)
# Out:
# array([[<AxesSubplot: title={'center': 'SepalLength_cm'}>,
#         <AxesSubplot: title={'center': 'SepalWidth_cm'}>],
#        [<AxesSubplot: title={'center': 'PetalLength_cm'}>,
#         <AxesSubplot: title={'center': 'PetalWidth_cm'}>]], dtype=object)

# %% [markdown]
# ## Scatter plots

# %%
iris_data['sepal_ratio']=iris_data['SepalLength_cm']/iris_data['SepalWidth_cm']
iris_data['petal_ratio']=iris_data['PetalLength_cm']/iris_data['PetalWidth_cm']
iris_data['sepal_petal_length']=iris_data['SepalLength_cm']/iris_data['PetalLength_cm']
iris_data['sepal_petal_width']=iris_data['SepalWidth_cm']/iris_data['PetalWidth_cm']
iris_data['sepal_petal_len:w']=iris_data['SepalLength_cm']/iris_data['PetalWidth_cm']
iris_data['sepal_petal_w:len']=iris_data['SepalWidth_cm']/iris_data['PetalLength_cm']
iris_data['id']=iris_data.index

sea.lmplot(x='id', y="sepal_ratio", data=iris_data, hue="Specie", fit_reg=False, legend=True)
sea.lmplot(x='id', y="petal_ratio", data=iris_data, hue="Specie", fit_reg=False, legend=True)
sea.lmplot(x='id', y="sepal_petal_length", data=iris_data, hue="Specie", fit_reg=False, legend=True)
sea.lmplot(x='id', y="sepal_petal_width", data=iris_data, hue="Specie", fit_reg=False, legend=True)
sea.lmplot(x='id', y="sepal_petal_len:w", data=iris_data, hue="Specie", fit_reg=False, legend=True)
sea.lmplot(x='id', y="sepal_petal_w:len", data=iris_data, hue="Specie", fit_reg=False, legend=True)

# %%
sea.pairplot(iris_data.drop(['id'], axis = 1),hue='Specie')

# %% [markdown]
# ### 1.3.1 How many features are there? What are the types of the features?
# <p>The iris dataset has 4 features: the length and width of petals and sepals. and 3 classes: versicolor, setosa and virginica.
# The Specie variable has categorical value while the sepal length, sepal width, petal length and petal width are numerical values since any aggregate function performed on them will hold meaning.</p>
#
# ### 1.3.2 From the histograms of the whole data, how do the shapes of the histograms for petal length and petal width differ from those for sepal length and sepal width? Is there a particular value of petal length (which ranges from 1.0 to 6.9) where the distribution of petal lengths (as illustrated by the histogram) could be best segmented into two parts?
# <p> Based on the obersvations made from histogram of four features
# <ol><li>the petal length and petal width histograms seem to be highly correlatred hence having them both in analysis might provide inaccurate results. </li>
# <li>The petal length and width plots are also of discontinuous style, while that of sepal are continuous in nature</li>
#     <li><b> The petal length plot can be divided at 2.5(between 2 and 3).</b></li>
# </ol></p>
#
# ### 1.3.3 Based upon these boxplots, is there a pair of features that appear to have significantly different medians? Recall that the degree of overlap between variabilities is an important initial indicator of the likelihood that differences in means or medians are meaningful. Also, based solely upon the box plots, which feature appears to explain the greatest amount of the data?
#
# </p> Based on the observation, sepal length and petal width show significantly different medians. </p>
# <p>As petal length has the largest range and inter quartile range, it appears to explain greatest amount of data.</p>
#
# ### 1.3.4 From the pairwise plots of the features, which features are most correlated from the plots? Mention at least three pairs.
# <p> The most correlated pairs in pairwise plots are:
# <ol>
#     <li>sepal length vs sepal width</li>
#     <li>petal length vs sepal length</li>
#     <li>petal width sepal length</li>
# </ol>
# </p>
# ### 1.3.5 Compare the histograms of each class to the histograms of the whole dataset. What differences do you see in the shapes?
# <p>
#     <ol>
#     <li>setosa vs whole data: Sepal length of setosa is larger than that compared to the avg of entire classes sepal length.</li>
#     <li>virginica vs whole data: </li>
#     <li>versicolor vs whole data: </li>
# </ol>
# </p>

# %% [markdown]
# # Q2 Air Quality dataset

# %%
airQ_data = pd.read_excel('/Users/aishakothare/DMT-F22/AirQualityUCI/AirQualityUCI.xlsx')
airQ_data.head()
# Out:
#         Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)   C6H6(GT)  \
# 0 2004-03-10  18:00:00     2.6      1360.00       150  11.881723
# 1 2004-03-10  19:00:00     2.0      1292.25       112   9.397165
# 2 2004-03-10  20:00:00     2.2      1402.00        88   8.997817
# 3 2004-03-10  21:00:00     2.2      1375.50        80   9.228796
# 4 2004-03-10  22:00:00     1.6      1272.25        51   6.518224
#
#    PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# 0        1045.50    166.0       1056.25    113.0       1692.00      1267.50
# 1         954.75    103.0       1173.75     92.0       1558.75       972.25
# 2         939.25    131.0       1140.00    114.0       1554.50      1074.00
# 3         948.25    172.0       1092.00    122.0       1583.75      1203.25
# 4         835.50    131.0       1205.00    116.0       1490.00      1110.00
#
#        T         RH        AH
# 0  13.60  48.875001  0.757754
# 1  13.30  47.700000  0.725487
# ...

# %%
airQ_data.isnull().sum()
# Out:
# Date             0
# Time             0
# CO(GT)           0
# PT08.S1(CO)      0
# NMHC(GT)         0
# C6H6(GT)         0
# PT08.S2(NMHC)    0
# NOx(GT)          0
# PT08.S3(NOx)     0
# NO2(GT)          0
# PT08.S4(NO2)     0
# PT08.S5(O3)      0
# T                0
# RH               0
# AH               0
# dtype: int64

# %%
airQ_data.shape
# Out:
# (9357, 15)

# %%
airQ_data.info
# Out:
# <bound method DataFrame.info of            Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)   C6H6(GT)  \
# 0    2004-03-10  18:00:00     2.6      1360.00       150  11.881723
# 1    2004-03-10  19:00:00     2.0      1292.25       112   9.397165
# 2    2004-03-10  20:00:00     2.2      1402.00        88   8.997817
# 3    2004-03-10  21:00:00     2.2      1375.50        80   9.228796
# 4    2004-03-10  22:00:00     1.6      1272.25        51   6.518224
# ...         ...       ...     ...          ...       ...        ...
# 9352 2005-04-04  10:00:00     3.1      1314.25      -200  13.529605
# 9353 2005-04-04  11:00:00     2.4      1162.50      -200  11.355157
# 9354 2005-04-04  12:00:00     2.4      1142.00      -200  12.374538
# 9355 2005-04-04  13:00:00     2.1      1002.50      -200   9.547187
# 9356 2005-04-04  14:00:00     2.2      1070.75      -200  11.932060
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# ...

# %% [markdown]
# ## Q2.1

# %%
airQ_data.describe()
# Out:
#             CO(GT)  PT08.S1(CO)     NMHC(GT)     C6H6(GT)  PT08.S2(NMHC)  \
# count  9357.000000  9357.000000  9357.000000  9357.000000    9357.000000
# mean    -34.207524  1048.869652  -159.090093     1.865576     894.475963
# std      77.657170   329.817015   139.789093    41.380154     342.315902
# min    -200.000000  -200.000000  -200.000000  -200.000000    -200.000000
# 25%       0.600000   921.000000  -200.000000     4.004958     711.000000
# 50%       1.500000  1052.500000  -200.000000     7.886653     894.500000
# 75%       2.600000  1221.250000  -200.000000    13.636091    1104.750000
# max      11.900000  2039.750000  1189.000000    63.741476    2214.000000
#
#            NOx(GT)  PT08.S3(NOx)      NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# count  9357.000000   9357.000000  9357.000000   9357.000000  9357.000000
# mean    168.604200    794.872333    58.135898   1391.363266   974.951534
# std     257.424561    321.977031   126.931428    467.192382   456.922728
# ...

# %%
airQ_data.var
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.var of            Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)   C6H6(GT)  \
# 0    2004-03-10  18:00:00     2.6      1360.00       150  11.881723
# 1    2004-03-10  19:00:00     2.0      1292.25       112   9.397165
# 2    2004-03-10  20:00:00     2.2      1402.00        88   8.997817
# 3    2004-03-10  21:00:00     2.2      1375.50        80   9.228796
# 4    2004-03-10  22:00:00     1.6      1272.25        51   6.518224
# ...         ...       ...     ...          ...       ...        ...
# 9352 2005-04-04  10:00:00     3.1      1314.25      -200  13.529605
# 9353 2005-04-04  11:00:00     2.4      1162.50      -200  11.355157
# 9354 2005-04-04  12:00:00     2.4      1142.00      -200  12.374538
# 9355 2005-04-04  13:00:00     2.1      1002.50      -200   9.547187
# 9356 2005-04-04  14:00:00     2.2      1070.75      -200  11.932060
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# ...

# %% [markdown]
# ## Q2.2

# %% [markdown]
# ### Histograms

# %%
airQ_data.loc[:, airQ_data.columns != 'Date'].hist(density=True, figsize=(20,10))
# Out:
# array([[<AxesSubplot: title={'center': 'CO(GT)'}>,
#         <AxesSubplot: title={'center': 'PT08.S1(CO)'}>,
#         <AxesSubplot: title={'center': 'NMHC(GT)'}>,
#         <AxesSubplot: title={'center': 'C6H6(GT)'}>],
#        [<AxesSubplot: title={'center': 'PT08.S2(NMHC)'}>,
#         <AxesSubplot: title={'center': 'NOx(GT)'}>,
#         <AxesSubplot: title={'center': 'PT08.S3(NOx)'}>,
#         <AxesSubplot: title={'center': 'NO2(GT)'}>],
#        [<AxesSubplot: title={'center': 'PT08.S4(NO2)'}>,
#         <AxesSubplot: title={'center': 'PT08.S5(O3)'}>,
#         <AxesSubplot: title={'center': 'T'}>,
#         <AxesSubplot: title={'center': 'RH'}>],
#        [<AxesSubplot: title={'center': 'AH'}>, <AxesSubplot: >,
#         <AxesSubplot: >, <AxesSubplot: >]], dtype=object)

# %%
airQ_data.plot(kind='box',layout=(4,1),figsize=(50,50),color='red',grid=True, fontsize=18, showfliers=False)
# Out:
# <AxesSubplot: >

# %%
airQ_data.boxplot(figsize=(30,30))
# Out:
# <AxesSubplot: >

# %% [markdown]
# ### Q2.3.1 From the histograms, what abnormality can you see?
# <p>In the histogram, its seen that the values for gas NMHC(GT), more than 90% are arond the -200 range hence this column can be dropped. </p>
#
# ### Q2.3.2 What abnormality can you see from the summary statistics?
# <p>The summary stats show alot of -200, this looks like an error.</p>
#
# ### Q2.3.3 How can you remove the abnormality from the data?
# <p> I can get rid of this abnormality by
#     <li>removing the NMHC column and replacing the -200 values over the dataframe with null.</li>
#     <li>Calculate a new estimate for the null values</li>
# </p>

# %% [markdown]
# ### Q2.3.4 Show how the histograms look after removing the abnormalities from the data?

# %%
airQ_data.columns
# Out:
# Index(['Date', 'Time', 'CO(GT)', 'PT08.S1(CO)', 'NMHC(GT)', 'C6H6(GT)',
#        'PT08.S2(NMHC)', 'NOx(GT)', 'PT08.S3(NOx)', 'NO2(GT)', 'PT08.S4(NO2)',
#        'PT08.S5(O3)', 'T', 'RH', 'AH'],
#       dtype='object')

# %%
airQ_data.drop('NMHC(GT)', axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [257], line 1
# ----> 1 airQ_data.drop('NMHC(GT)', axis=1, inplace=True)
#       2 airQ_data.replace(to_replace= -200, value= pd.NaN, inplace= True)
#
# File ~/opt/miniconda3/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/opt/miniconda3/lib/python3.9/site-packages/pandas/core/frame.py:4957, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4809 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
# ...

# %%
airQ_data=airQ_data.replace(-200, pd.NA)
airQ_data.isnull().sum()
# Out:
# Date                0
# Time                0
# CO(GT)           1683
# PT08.S1(CO)       366
# C6H6(GT)          366
# PT08.S2(NMHC)     366
# NOx(GT)          1639
# PT08.S3(NOx)      366
# NO2(GT)          1642
# PT08.S4(NO2)      366
# PT08.S5(O3)       366
# T                 366
# RH                366
# AH                366
# dtype: int64

# %%
airQ_data.columns
# Out:
# Index(['Date', 'Time', 'CO(GT)', 'PT08.S1(CO)', 'C6H6(GT)', 'PT08.S2(NMHC)',
#        'NOx(GT)', 'PT08.S3(NOx)', 'NO2(GT)', 'PT08.S4(NO2)', 'PT08.S5(O3)',
#        'T', 'RH', 'AH'],
#       dtype='object')

# %%
for i in airQ_data.columns[2:13]:
    airQ_data[i]=airQ_data[i].fillna(airQ_data[i].mean())

# %%
airQ_data.describe()
# Out:
#             CO(GT)  PT08.S1(CO)     C6H6(GT)  PT08.S2(NMHC)      NOx(GT)  \
# count  9357.000000  9357.000000  9357.000000    9357.000000  9357.000000
# mean      2.152750  1099.707856    10.082993     939.029205   246.881252
# std       1.316068   212.796116     7.302474     261.557856   193.419417
# min       0.100000   647.250000     0.149048     383.250000     2.000000
# 25%       1.200000   941.250000     4.591495     742.500000   112.000000
# 50%       2.152750  1074.500000     8.593367     923.250000   229.000000
# 75%       2.600000  1221.250000    13.636091    1104.750000   284.200000
# max      11.900000  2039.750000    63.741476    2214.000000  1479.000000
#
#        PT08.S3(NOx)      NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)            T  \
# count   9357.000000  9357.000000   9357.000000  9357.000000  9357.000000
# mean     835.370973   113.075515   1456.143486  1022.780725    18.316054
# std      251.741784    43.911095    339.365351   390.609000     8.658396
# ...
